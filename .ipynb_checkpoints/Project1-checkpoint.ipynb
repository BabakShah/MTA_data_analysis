# %% [markdown]
# # Challenge Set 1:  MTA Turnstile Data

# %%
from __future__ import print_function, division

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import seaborn as sns

# %matplotlib inline

# %%
import datetime

# %% [markdown]
# #### Exercise 1.1
#
# - Open up a new Jupyter notebook
# - Download a few MTA turnstile data files
# - Open up a file, use csv reader to read it, make a python dict where
#   there is a key for each (C/A, UNIT, SCP, STATION). These are the
#   first four columns. The value for this key should be a list of
#   lists. Each list in the list is the rest of the columns in a
#   row. For example, one key-value pair should look like
#
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
# ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
# ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
# ...
# ]
# }

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [170506, 170513, 170520, 170527]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6157740
# 1  REGULAR  6157777
# 2  REGULAR  6157810
# 3  REGULAR  6157963
# 4  REGULAR  6158212
#
#    EXITS
# 0                                            2085315
# 1                                            2085319
# 2                                            2085353
# 3                                            2085453
# 4                                            2085529

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
turnstiles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 785089 entries, 0 to 195462
# Data columns (total 11 columns):
# C/A         785089 non-null object
# UNIT        785089 non-null object
# SCP         785089 non-null object
# STATION     785089 non-null object
# LINENAME    785089 non-null object
# DIVISION    785089 non-null object
# DATE        785089 non-null object
# TIME        785089 non-null object
# DESC        785089 non-null object
# ENTRIES     785089 non-null int64
# EXITS       785089 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 71.9+ MB

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6157740  2085315
# 1  REGULAR  6157777  2085319
# 2  REGULAR  6157810  2085353
# 3  REGULAR  6157963  2085453
# 4  REGULAR  6158212  2085529

# %%
turnstiles_df.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 195458  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195459  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195460  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195461  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
# 195462  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/26/2017
#
#             TIME     DESC  ENTRIES  EXITS
# 195458  05:00:00  REGULAR     5554    299
# 195459  09:00:00  REGULAR     5554    299
# 195460  13:00:00  REGULAR     5554    299
# 195461  17:00:00  REGULAR     5554    299
# 195462  21:00:00  REGULAR     5554    299

# %%
# Three weeks of Data
turnstiles_df.DATE.value_counts().sort_index()
# Out:
# 04/29/2017    28387
# 04/30/2017    28041
# 05/01/2017    28082
# 05/02/2017    28165
# 05/03/2017    28115
# 05/04/2017    28494
# 05/05/2017    28006
# 05/06/2017    28023
# 05/07/2017    27946
# 05/08/2017    28693
# 05/09/2017    28344
# 05/10/2017    28104
# 05/11/2017    27908
# 05/12/2017    27843
# 05/13/2017    27993
# 05/14/2017    27983
# 05/15/2017    28150
# 05/16/2017    28081
# 05/17/2017    27977
# 05/18/2017    27845
# 05/19/2017    27446
# 05/20/2017    27908
# 05/21/2017    27877
# 05/22/2017    27925
# 05/23/2017    27979
# 05/24/2017    28055
# 05/25/2017    27953
# 05/26/2017    27766
# Name: DATE, dtype: int64

# %% [markdown]
# #### Exercise 1.2
#
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and
#  station of a specific turnstile), have a list again, but let the list
#  be comprised of just the point in time and the count of entries.
#
# This basically means keeping only the date, time, and entries fields
# in each list. You can convert the date and time into datetime objects
# -- That is a python class that represents a point in time. You can
# combine the date and time fields into a string and use the
# [dateutil](https://labix.org/python-dateutil) module to convert it
# into a datetime object. For an example check
# [this StackOverflow question](http://stackoverflow.com/questions/23385003/attributeerror-when-using-import-dateutil-and-dateutil-parser-parse-but-no).
#
# Your new dict should look something like
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# [datetime.datetime(2013, 3, 2, 3, 0), 3788],
# [datetime.datetime(2013, 3, 2, 7, 0), 2585],
# [datetime.datetime(2013, 3, 2, 12, 0), 10653],
# [datetime.datetime(2013, 3, 2, 17, 0), 11016],
# [datetime.datetime(2013, 3, 2, 23, 0), 10666],
# [datetime.datetime(2013, 3, 3, 3, 0), 10814],
# [datetime.datetime(2013, 3, 3, 7, 0), 10229],
# ...
# ],
# ....
# }

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
from datetime import datetime as dt

# %%
mask = ((turnstiles_df["C/A"] == "A002") & 
        (turnstiles_df["UNIT"] == "R051") & 
        (turnstiles_df["SCP"] == "02-00-00") & 
        (turnstiles_df["STATION"] == "59 ST"))
turnstiles_df[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6157740  2085315
# 1  REGULAR  6157777  2085319
# 2  REGULAR  6157810  2085353
# 3  REGULAR  6157963  2085453
# 4  REGULAR  6158212  2085529

# %%
# Take the date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, format="%m/%d/%Y %H:%M:%S")

# %%
# mask = ((turnstiles_df["C/A"] == "R626") & 
# (turnstiles_df["UNIT"] == "R062") & 
# (turnstiles_df["SCP"] == "00-00-00") & 
# (turnstiles_df["STATION"] == "CROWN HTS-UTICA")) 
# turnstiles_df[mask].head()

# %%
plt.plot(turnstiles_df['DATE_TIME'],turnstiles_df['ENTRIES'])

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'DATE_TIME'],
#       dtype='object')

# %%
turnstiles_df['hourly_entries'] = turnstiles_df.ENTRIES.shift(-1)-turnstiles_df.ENTRIES

# %%
turnstiles_df[mask].head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/29/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/30/2017  12:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME  hourly_entries
# 0  REGULAR  6157740  2085315 2017-04-29 00:00:00            37.0
# 1  REGULAR  6157777  2085319 2017-04-29 04:00:00            33.0
# 2  REGULAR  6157810  2085353 2017-04-29 08:00:00           153.0
# 3  REGULAR  6157963  2085453 2017-04-29 12:00:00           249.0
# 4  REGULAR  6158212  2085529 2017-04-29 16:00:00           309.0
# 5  REGULAR  6158521  2085589 2017-04-29 20:00:00           116.0
# 6  REGULAR  6158637  2085612 2017-04-30 00:00:00            17.0
# 7  REGULAR  6158654  2085617 2017-04-30 04:00:00             7.0
# 8  REGULAR  6158661  2085641 2017-04-30 08:00:00            42.0
# 9  REGULAR  6158703  2085730 2017-04-30 12:00:00            94.0

# %%
negatives = turnstiles_df.loc[(turnstiles_df.hourly_entries<0)]
negatives
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 41       A002  R051  02-00-00            59 ST  NQR456W      BMT  05/05/2017
# 83       A002  R051  02-00-01            59 ST  NQR456W      BMT  05/05/2017
# 125      A002  R051  02-03-00            59 ST  NQR456W      BMT  05/05/2017
# 1221     -7.390379e+06
# 1305     -2.857052e+06
# 1432     -1.980000e+02
# 1433     -6.900000e+01
# 1434     -3.560000e+02
# 1435     -4.590000e+02
# 1436     -5.630000e+02
# 1437     -5.120000e+02
# 1438     -1.570000e+02
# 1439     -6.400000e+01
# 1440     -2.720000e+02
# 1441     -4.300000e+02
# 1442     -5.380000e+02
# 1443     -3.600000e+02
# 1444     -6.700000e+01
# ...                ...
# 193637   -3.050000e+02
# 193638   -6.500000e+01
# 193639   -9.700000e+01
# 193640   -6.500000e+01
# 193641   -1.559177e+09
# 193684   -1.094090e+05
# 193727   -1.275980e+05
# 193770   -1.054410e+05
# 193813   -4.991700e+04
# 193856   -2.646050e+05
# 193942   -1.291140e+06
# 194071   -3.137694e+06
# 194114   -1.112800e+04
# 194284   -8.090172e+07
# 194326   -9.044600e+05
# 194368   -1.221340e+05
# 194410   -1.449263e+06
# 194536   -2.532090e+05
# 194578   -1.413990e+06
# 194662   -1.039367e+06
# 194704   -2.810000e+02
# 194788   -9.944000e+03
# 194830   -1.096400e+04
# 194914   -7.183169e+06
# 194998   -2.622060e+05
# 195122   -7.122540e+05
# 195163   -1.494705e+06
# 195247   -1.488864e+06
# 195290   -1.803496e+06
# 195376   -2.745155e+06
#
# [15515 rows x 13 columns]

# %%
# turnstiles_df = .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"]).ENTRIES.count().reset_index().sort_values("ENTRIES", ascending=False)

# %%
turnstiles_df.iloc[75:87]
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 75  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/04/2017  12:00:00
# 76  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/04/2017  16:00:00
# 77  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/04/2017  20:00:00
# 78  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  00:00:00
# 79  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  04:00:00
# 80  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  08:00:00
# 81  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  12:00:00
# 82  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  16:00:00
# 83  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/05/2017  20:00:00
# 84  A002  R051  02-03-00   59 ST  NQR456W      BMT  04/29/2017  00:00:00
# 85  A002  R051  02-03-00   59 ST  NQR456W      BMT  04/29/2017  04:00:00
# 86  A002  R051  02-03-00   59 ST  NQR456W      BMT  04/29/2017  08:00:00
#
#        DESC  ENTRIES    EXITS           DATE_TIME  hourly_entries
# 75  REGULAR  5585680  1237354 2017-05-04 12:00:00           246.0
# 76  REGULAR  5585926  1237400 2017-05-04 16:00:00           639.0
# 77  REGULAR  5586565  1237461 2017-05-04 20:00:00           220.0
# 78  REGULAR  5586785  1237486 2017-05-05 00:00:00            14.0
# 79  REGULAR  5586799  1237489 2017-05-05 04:00:00            25.0
# 80  REGULAR  5586824  1237531 2017-05-05 08:00:00           138.0
# 81  REGULAR  5586962  1237673 2017-05-05 12:00:00           109.0
# 82  REGULAR  5587071  1237697 2017-05-05 16:00:00           583.0
# 83  REGULAR  5587654  1237743 2017-05-05 20:00:00      -4683156.0
# 84  REGULAR   904498  3356866 2017-04-29 00:00:00            19.0
# 85  REGULAR   904517  3356892 2017-04-29 04:00:00            18.0
# 86  REGULAR   904535  3356974 2017-04-29 08:00:00           101.0

# %%
disgard = (turnstiles_df.hourly_entries<0)  | (turnstiles_df.hourly_entries>5100)
# turnstile_df.loc[disgard,:]
df_new=turnstiles_df.loc[~disgard,:]
df_new
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  04
# 7                  7.0
# 8                 42.0
# 9                 94.0
# 10               218.0
# 11                92.0
# 12                 9.0
# 13                50.0
# 14               165.0
# 15               264.0
# 16               779.0
# 17               134.0
# 18                 6.0
# 19                41.0
# 20               156.0
# 21               301.0
# 22               818.0
# 23               231.0
# 24                21.0
# 25                47.0
# 26               158.0
# 27               288.0
# 28               679.0
# 29               263.0
# ...                ...
# 195433             0.0
# 195434             0.0
# 195435             0.0
# 195436             0.0
# 195437             0.0
# 195438             0.0
# 195439             0.0
# 195440             0.0
# 195441             0.0
# 195442             0.0
# 195443             0.0
# 195444             0.0
# 195445             0.0
# 195446             0.0
# 195447             0.0
# 195448             0.0
# 195449             0.0
# 195450             0.0
# 195451             0.0
# 195452             0.0
# 195453             0.0
# 195454             0.0
# 195455             0.0
# 195456             0.0
# 195457             0.0
# 195458             0.0
# 195459             0.0
# 195460             0.0
# 195461             0.0
# 195462             NaN
#
# [760425 rows x 13 columns]

# %%
negatives = df_new.loc[(df_new.hourly_entries<0)]
negatives
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS, DATE_TIME, hourly_entries]
# Index: []

# %%
df_station=df_new.groupby(['STATION']).sum().sort_values(by='hourly_entries',ascending=False)
df_station.head(10)
# Out:
#                       ENTRIES         EXITS  hourly_entries
# STATION
# 34 ST-PENN STA   469046240327  267025925060       4061135.0
# GRD CNTRL-42 ST  447661173030  118526902254       3442718.0
# 34 ST-HERALD SQ  272242900503  219515877264       2889155.0
# 23 ST            634743167590  624108717415       2878679.0
# 14 ST-UNION SQ   179632898164   50475067937       2651031.0
# TIMES SQ-42 ST   643139580343  508189100223       2408698.0
# 42 ST-PORT AUTH  936383548280  706771579871       2266659.0
# FULTON ST        680570404131  699361883965       2224679.0
# 86 ST            402868736789  420643415605       2198810.0
# 125 ST           200605437424  134638575290       1879831.0

# %%
plt.plot(turnstiles_df['DATE_TIME'],turnstiles_df['STATION'])

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP          STATION           DATE_TIME  ENTRIES
# 108172  G001  R151  00-00-00  CONEY IS-STILLW 2017-05-09 05:00:00        2
# 697077  R504  R276  00-00-01   VERNON-JACKSON 2017-05-26 20:00:00        2
# 0       A002  R051  02-00-00            59 ST 2017-04-29 00:00:00        1
# 523407  R145  R032  00-00-02   TIMES SQ-42 ST 2017-05-13 00:00:00        1
# 523387  R145  R032  00-00-02   TIMES SQ-42 ST 2017-05-09 16:00:00        1

# %%
# On 9/16, we seem to have two entries for same time.  Let's take a look
mask = ((turnstiles_df["C/A"] == "R504") & 
(turnstiles_df["UNIT"] == "R276") & 
(turnstiles_df["SCP"] == "00-00-01") & 
(turnstiles_df["STATION"] == "VERNON-JACKSON") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2016, 9, 16).date()))
turnstiles_df[mask].head()
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS, DATE_TIME]
# Index: []

# %% [markdown]
# * Looks to be a incorrect AUD entry.  May be we should just select the Regular One.

# %%
turnstiles_df.DESC.value_counts()
# Out:
# REGULAR       782645
# RECOVR AUD      2444
# Name: DESC, dtype: int64

# %% [markdown]
# * Since we are only interested in Entries, we might be OK.

# %%
# Get rid of the duplicate entry
turnstiles_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True, ascending=False)
turnstiles_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0       A002  R051  02-00-00           59 ST 2017-04-29 00:00:00        1
# 523394  R145  R032  00-00-02  TIMES SQ-42 ST 2017-05-10 20:00:00        1
# 523385  R145  R032  00-00-02  TIMES SQ-42 ST 2017-05-09 08:00:00        1
# 523386  R145  R032  00-00-02  TIMES SQ-42 ST 2017-05-09 12:00:00        1
# 523387  R145  R032  00-00-02  TIMES SQ-42 ST 2017-05-09 16:00:00        1

# %% [markdown]
# * No more duplicate Entries

# %%
# Drop Exits and Desc Column.  To prevent errors in multiple run of cell, errors on drop is ignored
turnstiles_df = turnstiles_df.drop(["EXITS", "DESC"], axis=1, errors="ignore")

# %% [markdown]
# #### Exercise 1.3
#
# - These counts are for every n hours. (What is n?) We want total daily
#   entries.
#
# Now make it that we again have the same keys, but now we have a single
# value for a single day, which is the total number of passengers that
# entered through this turnstile on this day.

# %%
turnstiles_daily = turnstiles_df.groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"]).ENTRIES.first().reset_index()

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  04/29/2017  6158521
# 1  A002  R051  02-00-00   59 ST  04/30/2017  6159015
# 2  A002  R051  02-00-00   59 ST  05/01/2017  6160374
# 3  A002  R051  02-00-00   59 ST  05/02/2017  6161830
# 4  A002  R051  02-00-00   59 ST  05/03/2017  6163254

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily.groupby(["C/A", "UNIT", "SCP", "STATION"])
f["DATE", "ENTRIES"].transform(lambda grp: grp.shift(1)))
# Out:
#   File "<ipython-input-31-d860be2cf904>", line 2
#     f["DATE", "ENTRIES"].transform(lambda grp: grp.shift(1)))
#     ^
# SyntaxError: invalid syntax

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE  ENTRIES
# 0  A002  R051  02-00-00   59 ST  04/29/2017  6158521
# 1  A002  R051  02-00-00   59 ST  04/30/2017  6159015
# 2  A002  R051  02-00-00   59 ST  05/01/2017  6160374
# 3  A002  R051  02-00-00   59 ST  05/02/2017  6161830
# 4  A002  R051  02-00-00   59 ST  05/03/2017  6163254

# %%
turnstiles_daily.tail()
# Out:
#           C/A  UNIT       SCP        STATION        DATE  ENTRIES
# 130911  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/22/2017     5554
# 130912  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/23/2017     5554
# 130913  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/24/2017     5554
# 130914  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/25/2017     5554
# 130915  TRAM2  R469  00-05-01  RIT-ROOSEVELT  05/26/2017     5554

# %%
# Drop the rows for last date
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-8d910b9273d7> in <module>()
#       1 # Drop the rows for last date
# ----> 2 turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)
#
# /Users/babak/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3148                 check = indices == -1
#    3149                 if check.any():
# -> 3150                     raise KeyError(list(np.compress(check, subset)))
#    3151                 agg_obj = self.take(indices, axis=agg_axis)
#    3152
#
# KeyError: ['PREV_DATE']

# %%
turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]].head()
# Out:
#       C/A  UNIT       SCP     STATION        DATE    ENTRIES   PREV_DATE  \
# 715  A011  R080  01-00-00  57 ST-7 AV  08/28/2016  887688133  08/27/2016
# 716  A011  R080  01-00-00  57 ST-7 AV  08/29/2016  887685714  08/28/2016
# 717  A011  R080  01-00-00  57 ST-7 AV  08/30/2016  887683207  08/29/2016
# 718  A011  R080  01-00-00  57 ST-7 AV  08/31/2016  887680260  08/30/2016
# 719  A011  R080  01-00-00  57 ST-7 AV  09/01/2016  887677354  08/31/2016
#
#      PREV_ENTRIES
# 715   887689608.0
# 716   887688133.0
# 717   887685714.0
# 718   887683207.0
# 719   887680260.0

# %%
# What's the deal with counter being in reverse
mask = ((turnstiles_df["C/A"] == "A011") & 
(turnstiles_df["UNIT"] == "R080") & 
(turnstiles_df["SCP"] == "01-00-00") & 
(turnstiles_df["STATION"] == "57 ST-7 AV") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2016, 8, 27).date()))
turnstiles_df[mask].head()
# Out:
#        C/A  UNIT       SCP     STATION LINENAME DIVISION        DATE  \
# 1446  A011  R080  01-00-00  57 ST-7 AV      NQR      BMT  08/27/2016
# 1445  A011  R080  01-00-00  57 ST-7 AV      NQR      BMT  08/27/2016
# 1444  A011  R080  01-00-00  57 ST-7 AV      NQR      BMT  08/27/2016
# 1443  A011  R080  01-00-00  57 ST-7 AV      NQR      BMT  08/27/2016
# 1442  A011  R080  01-00-00  57 ST-7 AV      NQR      BMT  08/27/2016
#
#           TIME    ENTRIES           DATE_TIME
# 1446  20:00:00  887689608 2016-08-27 20:00:00
# 1445  16:00:00  887690085 2016-08-27 16:00:00
# 1444  12:00:00  887690472 2016-08-27 12:00:00
# 1443  08:00:00  887690738 2016-08-27 08:00:00
# 1442  04:00:00  887690800 2016-08-27 04:00:00

# %% [markdown]
# * Counter working in Reverse??? - WHHHAT

# %%
# Let's see how many stations have this problem

(turnstiles_daily[turnstiles_daily["ENTRIES"] < turnstiles_daily["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
     .size())
# Out:
# C/A    UNIT  SCP       STATION
# A011   R080  01-00-00  57 ST-7 AV         20
#              01-00-04  57 ST-7 AV         17
#              01-00-05  57 ST-7 AV         20
# A016   R081  03-06-01  49 ST               1
# A025   R023  01-03-02  34 ST-HERALD SQ    20
# A049   R088  02-05-00  CORTLANDT ST       15
# A066   R118  00-00-00  CANAL ST           20
# C019   R232  00-00-02  45 ST              20
# H003   R163  01-00-02  6 AV               20
# H023   R236  00-06-00  DEKALB AV          20
# J034   R007  00-00-02  104 ST             20
# JFK01  R535  00-00-01  HOWARD BCH JFK      1
#              00-00-02  HOWARD BCH JFK      1
#              00-00-03  HOWARD BCH JFK      2
# JFK02  R535  01-00-01  HOWARD BCH JFK      1
#              01-00-02  HOWARD BCH JFK      1
#              01-00-03  HOWARD BCH JFK      1
#              01-00-04  HOWARD BCH JFK      1
#              01-00-05  HOWARD BCH JFK      1
#              01-00-06  HOWARD BCH JFK      1
# JFK03  R536  00-00-01  JFK JAMAICA CT1     2
#              00-00-02  JFK JAMAICA CT1     2
#              00-00-03  JFK JAMAICA CT1     1
#              00-00-04  JFK JAMAICA CT1     1
#              00-00-05  JFK JAMAICA CT1     1
#              00-03-00  JFK JAMAICA CT1     1
#              00-03-01  JFK JAMAICA CT1     1
#              00-03-02  JFK JAMAICA CT1     1
#              00-03-03  JFK JAMAICA CT1     1
#              00-03-04  JFK JAMAICA CT1     1
#                                           ..
# PTH07  R550  00-01-02  CITY / BUS          1
# PTH16  R550  01-00-03  LACKAWANNA          1
#              01-02-03  LACKAWANNA          1
# PTH19  R549  02-00-01  NEWARK C            2
